# %%
import pandas as pd

df_livros = pd.read_csv("books_dataset.csv")
df_livros
# Out:
#                                                   title  \
# 0                                          Future Shock
# 1                                      Ready Player Two
# 2                                          Bag of Bones
# 3                    Journey to the Center of the Earth
# 4                                      How to Stop Time
# ...                                                 ...
# 5748                                   Machine Learning
# 5749       Machine Learning – Guia de Referência Rápida
# 5750       Machine Learning – Guia de Referência Rápida
# 5751                                 O Algoritmo Mestre
# 5752  Problemas Clássicos de Ciência da Computação c...
#
#                                   authors published_date categories  \
# 0                           Alvin Toffler           1981    Fiction
# 1                            Ernest Cline     2020-11-24    Fiction
# 2                            Stephen King     1999-06-01    Fiction
# ...
